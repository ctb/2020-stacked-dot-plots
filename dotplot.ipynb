# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

import importlib
import alignplot
importlib.reload(alignplot)

from alignplot import StackedDotPlot

# %% [markdown]
# ## a contaminated genbank genome as query (y axis)

# %%
dotplot = StackedDotPlot('GCA_003220225.1',
                         ['GCA_003222275.1',],
                         'list.csv', './genomes')
_ = dotplot()
# Out:
# ['./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz']
# found queryfile for GCA_003220225.1: ./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz
# found targetfile for GCA_003222275.1: ./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmp3mdmsv4c.
# shared w/Acidobacteria bacterium: 518.0kb

# %% [markdown]
# ## a contaminated genbank genome as target (x axis)

# %%
dotplot = StackedDotPlot('GCA_003222275.1',
                         ['GCA_003220225.1'],
                         'list.csv', './genomes')
_ = dotplot()
# Out:
# ['./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz']
# found queryfile for GCA_003222275.1: ./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz
# found targetfile for GCA_003220225.1: ./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmphvalka0e.
# shared w/Candidatus Rokubacteria bacterium: 484.0kb

# %% [markdown]
# ## TARA genome contaminated with genbank genome

# %%
dotplot = StackedDotPlot('TARA_ANW_MAG_00083', ('GCA_002171995.1',), 'list.csv', './genomes')
_ = dotplot()
# Out:
# ['./genomes/TARA_ANW_MAG_00083.fa']
# found queryfile for TARA_ANW_MAG_00083: ./genomes/TARA_ANW_MAG_00083.fa
# found targetfile for GCA_002171995.1: ./genomes/GCA_002171995.1_ASM217199v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmpm0zjsksx.
# shared w/GCA_002171995.1: 336.0kb

# %% [markdown]
# ## genbank genome x self

# %%
dotplot = StackedDotPlot('GCA_003222275.1',
                         ('GCA_003222275.1',),
                         'list.csv', './genomes')
x = dotplot()
# Out:
# ['./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz']
# found queryfile for GCA_003222275.1: ./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz
# found targetfile for GCA_003222275.1: ./genomes/GCA_003222275.1_ASM322227v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmptnfr2f40.
# shared w/Acidobacteria bacterium: 6462.0kb

# %% [markdown]
# ## contaminated genbank genome against self.

# %%
dotplot = StackedDotPlot('GCA_003220225.1',
                         ('GCA_003220225.1',),
                         'list.csv', './genomes')
x = dotplot()
# Out:
# ['./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz']
# found queryfile for GCA_003220225.1: ./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz
# found targetfile for GCA_003220225.1: ./genomes/GCA_003220225.1_ASM322022v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmpo3uzb8na.
# shared w/Candidatus Rokubacteria bacterium: 5958.0kb

# %% [markdown]
# ## a minorly contaminated pair of genbank genomes
#
# contaminant on y axis

# %%
dotplot = StackedDotPlot('GCF_001683825.1', ('GCF_000181835.1',), 'list.csv', './genomes')
x = dotplot()
# Out:
# ['./genomes/GCF_001683825.1_ASM168382v1_genomic.fna.gz']
# found queryfile for GCF_001683825.1: ./genomes/GCF_001683825.1_ASM168382v1_genomic.fna.gz
# found targetfile for GCF_000181835.1: ./genomes/GCF_000181835.1_ASM18183v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmpfuf8jkt7.
# shared w/Bacillus anthracis str. A0488: 244.0kb

# %%
## another tara genome, this time with two contaminants

# %%
dotplot = StackedDotPlot('TARA_PSE_MAG_00132', ('GCA_001550135.1', 'GCA_001641615.1'), 'list.csv', './genomes')
x = dotplot()
# Out:
# ['./genomes/TARA_PSE_MAG_00132.fa']
# found queryfile for TARA_PSE_MAG_00132: ./genomes/TARA_PSE_MAG_00132.fa
# found targetfile for GCA_001550135.1: ./genomes/GCA_001550135.1_ASM155013v1_genomic.fna.gz
# found targetfile for GCA_001641615.1: ./genomes/GCA_001641615.1_ASM164161v1_genomic.fna.gz
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmpr9e7_d7d.
# shared w/GCA_001550135.1: 94.0kb
# running nucmer & show-coords...
# ...done! reading output from /var/folders/y6/s1r3q87933s6gjdrtmts1npc0000gq/T/tmp0_d_dy7f.
# shared w/GCA_001641615.1: 44.0kb
